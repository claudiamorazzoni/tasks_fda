# %% [markdown]
# This is my solution to the Task 1. The autor is Claudia Morazzoni (G00387828@gmit.ie)

# %% [markdown]
# # Tasks Assessment for Fundamentals of Data Analysis

# %% [markdown]
# ## Task 1 - Def counts function
#
# The idea is to create a function named counts that takes a list as input and returns a dictionary.

# %% [markdown]
# First, to relate each element $(x1 - y1)$ of two sets $(x, y)$ in a binary way it is necessary to construct a function, as formalized in the history of mathematics.[1]
#
# ### $$ y=f(x) $$
#
#
# In Python, a function is a sequence of commands that performs some task and has a name. Its main purpose is to help us organize programs into pieces that correspond to how we imagine a solution to the problem.[2] In the definition of a function, the reserved word in the header is def, which is followed by the function name and some parameters in parentheses. The parameters specify what information, if any, you must provide before the function can be used. Another way of saying this is that the parameters specify what the function needs to perform its task. The return statement is followed by an expression that is calculated. Its value is returned to the caller.[3]

# %%
# The function name is add and it has two parameters
def add(x,y):
    z=x+y # The purpose of the function is to add the two parameters
    return z # The return will be the result of the addition

# %%
add(3,5) # To see how the function works you need to call it
# Out:
# 8

# %% [markdown]
# ##### Lists and dictionaries

# %% [markdown]
# Lists are similar to strings, which are a sequence of characters, however, unlike strings, items in a list can be of different types.
#
# An object is a value to which a variable can refer or point and can be identified using its identifiers, which are unique. We can test whether two names refer to the same object using the is operator.

# %% [markdown]
# ![ABobject.png](attachment:ABobject.png)![Aobject.png](attachment:Aobject.png)

# %%
# The variable a and b receive the same value
a = "banana"
b = "banana"

print(a is b) # The is operator returns True if the two references are to the same object.
# Out:
# True

# %% [markdown]
# This is not the case with lists. Consider the example below. Here "a" and "b" refer to two different lists, each of which happens to have the same elements as values.

# %%
a = [81, 82, 83]
b = [81, 82, 83]

print(a is b)
print(a == b)
# Out:
# False
# True

# %% [markdown]
# ![abnoobject.png](attachment:abnoobject.png)

# %% [markdown]
# "a" and "b" have the same value but do not apply to the same object. In this case, they take a place (index) in the computer's memory.

# %% [markdown]
# A dictionary is a type of data structure of the collection type, that is, an object that contains more than one value. Unlike lists in which elements are accessed through a position or index, in dictionaries, information is accessed using keys. The elements of a dictionary are stored in an unordered manner. They use a pair structure containing key and value "{key:value}", so that their elements are unique, although the elements of a value can be duplicated since the key is different.

# %%
a = {"d1":81, "d2":82, "d3":83}
b = {"d1":81, "d2":82, "d3":83}
c = {"d4":81, "d5":82, "d6":83}
d = {"d1":86, "d2":85, "d3":86}

print(a is b)
print(a == b)
print(b == c)
print(d == a)
# Out:
# False
# True
# False
# False

# %% [markdown]
# "a" and "b" have the same key but do not apply to the same object. "c" does not have the same key so do not apply to the same object and "d" have the same key but not the same value so do not apply to the same object.

# %% [markdown]
# ##### Count inbuilt function

# %% [markdown]
# We know that Python's count inbuilt function counts how many times an item appears in a list. [4]

# %%
# List of numbers
numbers = [1, 4, 2, 9, 7, 8, 9, 3, 9]

# variable x receives the count method with a parameter 
x = numbers.count(9)

print(x)
# Out:
# 3

# %% [markdown]
# ##### List comprehension

# %% [markdown]
# List comprehension is generally used for code optimization and performance. [5]
# Suppose we want to add items from one list to another list.

# %%
# Creating any list and an empty list
old_list = [1,2,3,4,5,6]
new_list = []

# At first we could use this code o include numbers in the new list (for loop)
for i in old_list:
    new_list.append(i)

print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Using list comprehension we optimize the lines of code and increase efficiency.

# %%
## Creating any list
old_list = [5,6,7,8]

# Applying list comprehension to the "new list"
new_list = [i for i in old_list]

print(new_list)
# Out:
# [5, 6, 7, 8]

# %% [markdown]
# As we see in the list comprehension we first insert the variables we want as a result and then we insert the function for that to happen.

# %% [markdown]
# ##### Dict () constructor

# %% [markdown]
# Finally, to finish our reasoning sequence for building the counts function, let's turn the result (key-value pairs) into a dictionary. The dict () constructor creates dictionaries directly from strings of key-value pairs.[6]

# %%
# Creating a list with tuples inside to simulate a pair of values, as the dictionary requires.
l1 = [("banana", 81),("orange", 84)]

# Transforming the list into a dictionary
l2 = dict(l1) 

print(l2)
# Out:
# {'banana': 81, 'orange': 84}

# %% [markdown]
# ##### Def Counts

# %%
def counts (l):
    """ 
    A function named counts that takes a list as input and returns a dictionary
    """
    # list comprehension using for loop and count function to get the number of occurrences os each item, thus forming the pair that a dictionary requires
    return (dict ((x,l.count(x)) for x in l))

# %% [markdown]
# ##### Tests of the function
# Here we test the function with some known values.

# %%
# Test the function with a string list
l=['a', 'b', 'c', 'a', 'b', 'c', 'c', 'a']

# %%
# calling the function
counts(l)
# Out:
# {'a': 3, 'b': 2, 'c': 3}

# %%
# calling the function with an argument inside
counts(["B","B", "C", ('ana', '10', '4')])
# Out:
# {'B': 2, 'C': 1, ('ana', '10', '4'): 1}

# %% [markdown]
# ##### References - task 1

# %% [markdown]
# [1]Function (mathematics);https://en.wikipedia.org/wiki/Function_(mathematics)#:~:text=A%20function%20is%20a%20process,the%20codomain%20of%20the%20function.
#
# [2] Glossary - Python Documentation;https://docs.python.org/3.0/glossary.html
#
# [3] Python Functions;https://www.w3schools.com/python/python_functions.asp#:~:text=A%20function%20is%20a%20block,return%20data%20as%20a%20result
#
# [4] Python list function | count();https://www.geeksforgeeks.org/python-list-function-count/
#
# [5] List Comprehensions in Python;https://www.pythonforbeginners.com/basics/list-comprehensions-in-python
#
# [6] Data Structures;https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# ## Task 2 - Dicerolls function
#
# The idea is to create a function named dicerolls that is should simulate randomly rolling dice n times, keeping track of each total face value. It should then return a dictionary with the number of times each possible total face value occurred.

# %% [markdown]
# ##### Random numbers

# %% [markdown]
# To generate our random numbers from 1 to 6, simulating a dice, we will define the function generates () which has no parameter and will obviously return an integer from 1 to 6.
#
# For this, we will use the random library randint function. [1] This function takes arguments 1 and 6, to generate integers from 1 to 6. And to use it, we have to import the random module.

# %%
import random as rd

print(rd.randint(3, 9)) # Return a number between 3 and 9 (both included):
# Out:
# 3

# %% [markdown]
# ##### If , Elif and Else Statement

# %% [markdown]
# Before storing the data, the function needs to know how much data we are playing with, so the "if" conditionals make the rule of one or more dice clear. [2]

# %%
a = 200
b = 33
if b > a: # An "if statement" is written by using the if keyword.
  print("b is greater than a")
elif a == b: # The elif keyword is pythons way of saying "if the previous conditions were not true, then try this condition".
  print("a and b are equal")
else: # The else keyword catches anything which isn't caught by the preceding conditions.
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ##### Loop

# %% [markdown]
# Now, let's create a way to repeat n rolls of a die, where n the user will choose how many times to roll the dice.
#
# Loops help you execute a sequence of instructions until a condition is satisfied. Here we choose "while" loop. The concept behind a while loop is simple: While a condition is true -> Run my commands. The while loop will check the condition every time, and if it returns "true" it will execute the instructions within the loop. [3]

# %% [markdown]
# ![while-loop.jpg](attachment:while-loop.jpg)

# %% [markdown]
# ##### Global and local variables

# %% [markdown]
# To store the numbers drawn we will use a local variable. Variables that are created outside of a function (as in all of the examples above) are known as global variables. [4]

# %%
# This function uses global variable s 
def f():  
    print(s)  
  
# Global scope 
s = "I love Geeksforgeeks"
f()
# Out:
# I love Geeksforgeeks

# %% [markdown]
# The variable s is defined as the string “I love Geeksforgeeks” before we call the function f(). The only statement in f() is the “print s” statement. As there is no local s, the value from the global s will be used.

# %%
# This function has a variable with 
# name same as s. 
def f():  
    s = "Me too."
    print(s) 
  
# Global scope 
s = "I love Geeksforgeeks" 
f() 
print(s)
# Out:
# Me too.
# I love Geeksforgeeks

# %% [markdown]
# If a variable with the same name is defined inside the scope of function as well then it will print the value given inside the function only and not the global value.

# %% [markdown]
# ##### Finally the dicerolls function

# %%
import random as rd

def dicerolls (k=1, n=10):
    """ 
    A function named dicerolls that simulate randomly rolling dice n times and returns a dictionary with the number of times each possible total face value occurred
    """
    cont = 0  # We need an interactor for the loop count
    d0 = [] # We need an empty list to store the drawn data
    if k==1:
        while True: # The loop just finish when cont >= n
            dn = [d0.append(rd.randint(1,6))] # We need an empty local list to store the data
            if cont < n:
                cont += 1
                if cont >= n:
                    return (dict((x,d0.count(x)) for x in d0)) # # list comprehension to get the number of occurrences os each item, thus forming the pair that a dictionary requires
    elif k>=2:
        t=k*1 # when we are playing with 2 or more dices
        s=k*6 # when we are playing with 2 or more dices
        while True:
            d0.append(rd.randint(t,s)) # t and s to delimit the number of numbers to be drawn
            if cont < n:
                cont += 1
                if cont >= n:
                    return (dict((x,d0.count(x)) for x in d0)) 
    else:
        return print("You can only play with integers numbers") # a exception when the player When the player types 0 or a float number

# %% [markdown]
# ##### Tests of the function
# Here we test the function with some known values.

# %%
# caling the function with 1 dice
dicerolls(1,100)
# Out:
# {1: 13, 2: 15, 3: 29, 6: 15, 4: 15, 5: 13}

# %%
# caling the function with 3 dices
dicerolls(3,100)
# Out:
# {15: 4,
#  13: 7,
#  8: 5,
#  5: 5,
#  10: 4,
#  18: 8,
#  17: 5,
#  3: 6,
#  6: 5,
#  4: 6,
#  11: 6,
#  16: 8,
#  7: 8,
#  12: 10,
#  14: 8,
#  9: 5}

# %% [markdown]
# ##### References - task 2

# %% [markdown]
# [1] numpy.random.randint; https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html
#
# [2] Python if...else Statement: https://www.programiz.com/python-programming/if-elif-else
#
# [3] Python While Loop Tutorial – Do While True Example Statement: https://www.freecodecamp.org/news/python-while-loop-tutorial-do-while-true-example-statement/
#
# [4] Python Global Variables: https://www.w3schools.com/python/gloss_python_global_variables.asp

# %% [markdown]
# ## Task 3 -  Flipping a coin

# %% [markdown]
# The idea is to simulate the game of a coin with 50/50 heads and tails and we'll find out how it works if we play 1000 times.

# %% [markdown]
# Here we will understand that each of the functions that we write can be used and called by the other functions that we write. This is one of the most important ways that allows computer scientists to take a big problem and break it down into a group of smaller problems. This process of breaking down a problem into smaller subproblems is called functional decomposition.[1]

# %% [markdown]
# ![04-functional-decomp.png](attachment:04-functional-decomp.png)

# %% [markdown]
# Here is a simple example of functional decomposition using two functions. The first, called square, simply computes the square of a given number. A second, called square_sum, uses the square function to determine the sum of the square of three numbers.

# %%
# The square function returns the result of multiplying the values of x and y
def square(x): 
    y = x * x
    return y

# The squere_sum function returns the result of the addition after the square function is called
def square_sum(x,y,z): # the values of y, x and z at first are -5, 2 and 10
    a = square(x) # calling the square function three time
    b = square(y)
    c = square(z)
    return a+b+c

a = -5
b = 2
c = 10

result = square_sum(a,b,c) # calling the square_sum function
print(result)
# Out:
# 129

# %% [markdown]
# Although this is a very simple idea, in practice this example illustrates many important concepts in Python, including local and global variables, as explained in the previous task, along with passing parameters.
#
# In this way we will continue with the flipping_a_coin function itself for this task.

# %%
# First it will be necessary to import the numpy and random libraries
import numpy as np
import random as rd

# here we declare two variables in the form of an opposite dictionary so that we can capture the number of heads and tails drawn
id_coin = {0: 'tail', 1: 'head'}
coin_id = {'tail': 0, 'head': 1}

# the flippinig_a_coin function returns a number (or zero or one) drawn that will determine whether heads or tails
def  flipping_a_coin():
    return  id_coin[rd.randint(0,1)]

# this function returns the number of heads and tails per round
def playing_n_times(n=10, printer=True):
    global n_heads
    global n_tails
    global results
    
    if printer:
        results=[]
        for i in range(n):
            results.append(coin_id[flipping_a_coin()])
            n_heads = sum(results)
            n_tails = n-n_heads
            
    if printer:
        print(f'Round')
        print(f'heads - {n_heads} times')
        print(f'tails - {n_tails} times')
    return results, n_heads, n_tails



n_heads_round = []
n_tails_round = []

# this function calls the playing_n_times function and has a loop for the number of rounds
def number_round(n_round = 10, play_per_round = 10):
    print(f'Flipping a coin {play_per_round} times in {n_round} rounds\n')
    for rounds in range(n_round):
        _, n_heads, n_tails = playing_n_times(play_per_round, True) # calling the Playing_n_times function
        n_heads_round.append(n_heads) # it acumulates the results from n_heads in playing_n_times function
        n_tails_round.append(n_tails) # it acumulates the results from n_heads in playing_n_times function
       
        
        
    
number_round(1000,15) # calling the number_round function
# Out:
# Flipping a coin 15 times in 1000 rounds
#
# Round
# heads - 6 times
# tails - 9 times
# Round
# heads - 11 times
# tails - 4 times
# Round
# heads - 7 times
# tails - 8 times
# Round
# heads - 4 times
# tails - 11 times
# Round
# heads - 7 times
# tails - 8 times
# Round
# heads - 8 times
# tails - 7 times
# Round
# heads - 5 times
# tails - 10 times
# Round
# heads - 6 times
# tails - 9 times
# Round
# heads - 6 times
# tails - 9 times
# Round
# heads - 7 times
# tails - 8 times
# Round
# heads - 9 times
# tails - 6 times
# Round
# heads - 10 times
# tails - 5 times
# Round
# heads - 12 times
# tails - 3 times
# Round
# heads - 8 times
# tails - 7 times
# Round
# heads - 12 times
# tails - 3 times
# Round
# heads - 10 times
# tails - 5 times
# Round
# heads - 6 times
# tails - 9 times
# Round
# heads - 8 times
# tails - 7 times
# Round
# heads - 5 times
# tails - 10 times
# Round
# heads - 4 times
# tails - 11 times
# Round
# heads - 7 times
# tails - 8 times
# Round
# ...

# %%
# ploting the results of the heads to represent the resulting list of 1,000 numbers
import matplotlib.pyplot as plt
_=plt.hist(n_heads_round, 100)
plt.title('Frequency of the number of heads')
# Out:
# Text(0.5, 1.0, 'Frequency of the number of heads')

# %%
# ploting the results of the tails to represent the resulting list of 1,000 numbers
n, bins, patches = plt.hist(n_tails_round, 100, density=True, facecolor='g', alpha=0.75)
plt.title('Frequency of the number of tails')
# Out:
# Text(0.5, 1.0, 'Frequency of the number of tails')

# %% [markdown]
# With this histogram, we arrive here at what we call binomial distribution, very common in the observation of natural elements.
#
# The binomial distribution is the distribution of probability and discrete statistics of the number of successes resulting from a given sequence of attempts, which follow the following characteristics:[2]
#
# - Finite sample space;
#
# - Only two possible outcomes (success or failure) for each attempt;
#
# - All elements must have equal chances of occurrence;
#
# - Events must be independent of each other.
#
#
# We can confirm that the above distribution is equivalent to the binomial distribution by comparing the previous graph with a plot of the binomial function in Numpy.[3]

# %%
# Ploting the binomial function of numpy.random with the same parameters as the previous graphs.
X = np.random.binomial(15,0.5,1000)
plt.hist(X, 100)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   4.,   0.,   0.,
#           0.,   0.,   0.,   0.,   0.,  14.,   0.,   0.,   0.,   0.,   0.,
#           0.,   0.,   0.,  40.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,
#          95.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 151.,   0.,   0.,
#           0.,   0.,   0.,   0.,   0.,   0., 196.,   0.,   0.,   0.,   0.,
#           0.,   0.,   0., 217.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,
#         156.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,  87.,   0.,
#           0.,   0.,   0.,   0.,   0.,   0.,  23.,   0.,   0.,   0.,   0.,
#           0.,   0.,   0.,  14.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,
#           2.]),
#  array([ 1.  ,  1.12,  1.24,  1.36,  1.48,  1.6 ,  1.72,  1.84,  1.96,
#          2.08,  2.2 ,  2.32,  2.44,  2.56,  2.68,  2.8 ,  2.92,  3.04,
#          3.16,  3.28,  3.4 ,  3.52,  3.64,  3.76,  3.88,  4.  ,  4.12,
#          4.24,  4.36,  4.48,  4.6 ,  4.72,  4.84,  4.96,  5.08,  5.2 ,
# ...

# %% [markdown]
# ##### References - task 3

# %% [markdown]
# [1] Problem Decomposition: https://nyu-cds.github.io/python-mpi/04-decomposition/#:~:text=Numerical%20integration-,Functional%20decomposition,portion%20of%20the%20overall%20work.
#
# [2] Binomial Distribution: https://en.wikipedia.org/wiki/Binomial_distribution
#
# [3] Numpy Random Binomial: https://numpy.org/doc/stable/reference/random/generated/numpy.random.binomial.html

# %% [markdown]
# ## Task 4 - Simpson’s Paradox

# %% [markdown]
# Simpson’s Paradox occurs when trends that appear when a dataset is separated into groups reverse when the data are aggregated.[1] The paradox can be resolved when causal relations are appropriately addressed in the statistical modeling.
#
#
# At this point we will try to reproduce a real-life example from a medical study comparing the success rates of two treatments for kidney stones.

# %%
# we import all the libraries needed for calculations
import pandas as pd
import numpy as np
import random as rd
from statistics import mean
import seaborn as sns

# %% [markdown]
# Through the linspace function, as requested in this task, we will try to reproduce the data with the number of treatments for treatments involving small and large kidney stones, where Treatment A includes open surgical procedures and Treatment B includes closed surgical procedures.

# %%
# We created four variables representing each group
a = np.linspace(87, 81, 2)
b = np.linspace(270, 234, 2)
a1 = np.linspace(263, 192, 2)
b1 = np.linspace(80, 55, 2)

# %%
A = np.meshgrid(a, sparse=True)  # we create sparse output arrays for each group
A
# Out:
# [array([87., 81.])]

# %%
B = np.meshgrid(b)  
B
# Out:
# [array([270., 234.])]

# %%
A1 = np.meshgrid(a1)  
A1
# Out:
# [array([263., 192.])]

# %%
B1 = np.meshgrid(b1)  
B1
# Out:
# [array([80., 55.])]

# %%
# here we transform our variables into Dataframe
dfa = pd.DataFrame(A, columns=['TS', 'S']) 
dfa
# Out:
#      TS     S
# 0  87.0  81.0

# %%
dfb = pd.DataFrame(B, columns=['TS', 'S'])
dfb
# Out:
#       TS      S
# 0  270.0  234.0

# %%
dfa1 = pd.DataFrame(A1, columns=['TB', 'B'])
dfa1
# Out:
#       TB      B
# 0  263.0  192.0

# %%
dfb1 = pd.DataFrame(B1, columns=['TB', 'B'])
dfb1
# Out:
#      TB     B
# 0  80.0  55.0

# %%
# here we join the dataframes
df1 = pd.concat([dfa, dfb])
df1.reset_index(drop=True)
df1
# Out:
#       TS      S
# 0   87.0   81.0
# 0  270.0  234.0

# %%
# we apply the lambda function to calculate the percentage between columns, the axis = 1 refers to columns and axis = 1 rows
df1['s%'] = df1.apply(lambda x: x['S']/ x['TS'], axis=1).round(2)*100
df1
# Out:
#       TS      S    s%
# 0   87.0   81.0  93.0
# 0  270.0  234.0  87.0

# %%
df2 = pd.concat([dfa1, dfb1])
df2.reset_index(drop=True)
df2
# Out:
#       TB      B
# 0  263.0  192.0
# 0   80.0   55.0

# %%
df2['b%'] = df2.apply(lambda x: x['B']/ x['TB'], axis=1). round(2)*100
df2
# Out:
#       TB      B    b%
# 0  263.0  192.0  73.0
# 0   80.0   55.0  69.0

# %%
df0 = [df1, df2]
df = pd.concat(df0, axis=1, join='inner')
df.reset_index(drop=True)
df
# Out:
#       TS      S    s%     TB      B    b%
# 0   87.0   81.0  93.0  263.0  192.0  73.0
# 0  270.0  234.0  87.0   80.0   55.0  69.0

# %%
# here we create a new column to add the two variables and calculate the percentage and finally we have all the numbers that we needed
df['Both %'] = df.apply(lambda x: (x['S']+ x['B'])/ (x['TS']+ x['TB']), axis=1). round(2)*100
#df2['b%'] = df2.apply(lambda x: x['TS']/ x['S'], axis=1). round(2)*100
df
# Out:
#       TS      S    s%     TB      B    b%  Both %
# 0   87.0   81.0  93.0  263.0  192.0  73.0    78.0
# 0  270.0  234.0  87.0   80.0   55.0  69.0    83.0

# %%
# plotting the correlation between the variables
df.plot(x='S', y='B')

# %% [markdown]
# Another intriguing version of Simpson’s Paradox occurs when a correlation that points in one direction in stratified groups becomes a correlation in the opposite direction when aggregated for the population.

# %%
# plotting the correlation between the variables
df.plot(x='S', y='Both %')

# %% [markdown]
# ##### Linear regression

# %% [markdown]
# To figure out how to resolve the paradox, we need to look beyond the data we are shown and reason through the data generation process — what caused the results.
#
# Linear regression is a methodology developed from statistics and econometrics. This method is used to evaluate the effects that other variables have on an analyzed variable. [2]
#
# The relationship starts from a variable of interest (dependent) with others that may influence it.
#
# With the results obtained, linear regression visualizes the biggest trends that the analyzed variables present. The regression consists of statistically modeling the values ​​to be observed.
#
# This regression is linear when the events observed on a scatter plot indicate a trend in a straight line format, as we saw earlier.

# %% [markdown]
# Linear regression is simple when only two variables are analyzed, usually X and Y, one of which is dependent (Y) and the function of another that behaves independently (X).
#
# Simple linear regression is analyzed using the formula:
#
# ### $$ y = m*x+c $$
#
# Where "c" is the linear coefficient and "m" is the slope or regression coefficient. [3]

# %% [markdown]
# ##### How to program the best fit slope - "m"

# %% [markdown]
# To find the value of c and m we will try to reproduce it according to the formula below.

# %% [markdown]
# ![linearregressionequations.bmp](attachment:linearregressionequations.bmp)

# %%
# assigning one of the columns in x and y
x = df['S']
x
# Out:
# 0     81.0
# 0    234.0
# Name: S, dtype: float64

# %%
# assigning one of the columns in x and y
y = df['B']
y
# Out:
# 0    192.0
# 0     55.0
# Name: B, dtype: float64

# %%
m = ((len(y) * (x*y).sum() - x.sum()*y.sum())/ (len(y)*(x**2).sum() - (x.sum())**2)).round(2)
m
# Out:
# -0.9

# %%
c = ((y.sum() - m * x.sum()) / len(y)). round(2)
c
# Out:
# 265.25

# %%
# we transform the result into an array to reintegrate into our dataframe

def y(x):
    pred = np.array(m*x+c)
    return pred
y(x)
pred = np.array(m*x+c)
#pred

# %%
dfpred = pd.DataFrame(np.array([pred]).reshape(2,1), columns = ['pred'])
df.reset_index(drop=True)
dfpred
# Out:
#      pred
# 0  192.35
# 1   54.65

# %%
df.reset_index(drop=True, inplace=True)
dfpred.reset_index(drop=True, inplace=True)
dfpredi= pd.concat([df, dfpred], axis=1, join='inner')
dfpredi
# Out:
#       TS      S    s%     TB      B    b%  Both %    pred
# 0   87.0   81.0  93.0  263.0  192.0  73.0    78.0  192.35
# 1  270.0  234.0  87.0   80.0   55.0  69.0    83.0   54.65

# %%
dfpredi.plot(x='S', y= 'pred')

# %% [markdown]
# ##### Why Simpson’s Paradox Matters

# %% [markdown]
# Simpson’s Paradox is important because it reminds us that the data we are shown is not all the data there is. We can’t be satisfied only with the numbers or a figure, we have to consider the data generation process — the causal model — responsible for the data. Once we understand the mechanism producing the data, we can look for other factors influencing a result that are not on the plot. Thinking causally is not a skill most data scientists are taught, but it’s critical to prevent us from drawing faulty conclusions from numbers. We can use our experience and domain knowledge — or those of experts in the field — in addition to data to make better decisions.

# %% [markdown]
# ##### Linear model

# %%
e = (np.linspace(1, 200, 1000))
f = (np.linspace(300,500, 1000))
g = (np.linspace(450, 250, 1000))
h = (np.linspace(350,150, 1000))

# %%
dfe = pd.DataFrame(e, columns=['X'])
dff = pd.DataFrame(f, columns=['W'])
dfg = pd.DataFrame(g, columns=['Z'])
dfh = pd.DataFrame(h, columns=['Y'])

# %%
df_final = pd.concat([dfe,dff,dfg,dfh], axis=1, join='inner')

# %%
X = df_final['X'].values
y = df_final['Z'].values
X.shape # it is in vector format
# Out:
# (1000,)

# %%
# we transform it into matrix format
X = X.reshape(-1, 1) 
y = y.reshape(-1, 1)
X.shape # now it has 100 rows and 1 column
# Out:
# (1000, 1)

# %% [markdown]
# ##### Finding parameters with Sklearn

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1) 
X_train.shape, X_test.shape
# Out:
# ((900, 1), (100, 1))

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# constant C
regressor.intercept_
# Out:
# array([451.00502513])

# %%
# coefficient m
regressor.coef_
# Out:
# array([[-1.00502513]])

# %% [markdown]
# ##### Applying the notation y = m * x + c

# %%
regressor.predict(X)
# Out:
# array([[450.        ],
#        [449.7997998 ],
#        [449.5995996 ],
#        [449.3993994 ],
#        [449.1991992 ],
#        [448.998999  ],
#        [448.7987988 ],
#        [448.5985986 ],
#        [448.3983984 ],
#        [448.1981982 ],
#        [447.997998  ],
#        [447.7977978 ],
#        [447.5975976 ],
#        [447.3973974 ],
#        [447.1971972 ],
#        [446.996997  ],
#        [446.7967968 ],
#        [446.5965966 ],
#        [446.3963964 ],
#        [446.1961962 ],
#        [445.995996  ],
#        [445.7957958 ],
#        [445.5955956 ],
#        [445.3953954 ],
#        [445.1951952 ],
#        [444.99499499],
#        [444.79479479],
#        [444.59459459],
#        [444.39439439],
#        [444.19419419],
#        [443.99399399],
#        [443.79379379],
#        [443.59359359],
#        [443.39339339],
#        [443.19319319],
#        [442.99299299],
#        [442.79279279],
#        [442.59259259],
#        [442.39239239],
#        [442.19219219],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X, regressor.predict(X), color='red')

# %%
#R2 - how much the model fits the data - the explanatory strength of the model - closer to "one" better is the model
regressor.score(X_train, y_train)
# Out:
# 1.0

# %%
regressor.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ##### References - task 4

# %% [markdown]
# [1] Simpson’s Paradox: How to Prove Opposite Arguments with the Same Data: https://towardsdatascience.com/simpsons-paradox-how-to-prove-two-opposite-arguments-using-one-dataset-1c9c917f5ff9
#
# [2] Linear regression: https://en.wikipedia.org/wiki/Linear_regression#:~:text=In%20statistics%2C%20linear%20regression%20is,as%20dependent%20and%20independent%20variables)
#
# [3] Regression - How to program the Best Fit Slope: https://pythonprogramming.net/how-to-program-best-fit-line-slope-machine-learning-tutorial/
#
# [2] Merge, join, and concatenate: https://pandas.pydata.org/pandas-docs/version/0.17.0/merging.html
